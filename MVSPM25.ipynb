# %%
# Tratamiento de datos
import pandas as pd
# Almacenar en caché los resultados de funciones en el disco
import joblib
# Metricas para evaluación del modelo
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import median_absolute_error
# Creación de modelo de maquinas de soporte vectorial
from sklearn.svm import SVR
# Separar los datos entrenamiento y prueba
from sklearn.model_selection import train_test_split
# Optimización de hiperparametros
from sklearn.model_selection import GridSearchCV
# Uso de validacion cruzada
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

# %%
# Exportamos los datos del archivo dataSetLimpio4 dado que tiene algunas manipulaciones de las columnas en una clasificacion categorica, eliminamos valores nulos, contaminación 0.5 y quitamos registros atipicos
limpiaDataSetCalidadAire = pd.read_csv('data/stage/dataSetLimpio4.csv')
limpiaDataSetCalidadAire.shape
# Out:
# (19447, 25)

# %%
# Revisamos el comportamiento por toma de muestras de los datos y usando variación entre columnas.
# Nota: Se estaba presentando buen comportamiento entre algunos meses del dataset, por ende,
# revisamos algunos registros por meses para identificar diferenciaciones.
# Finalmente, dejamos el dataset completo con la línea siguiente:
limpiaDataSetCalidadAire =limpiaDataSetCalidadAire.sample(n = 19447, random_state=123).iloc[:,:]
limpiaDataSetCalidadAire
# Out:
#        anio  mes  dia  hora  pm25  festivo  temperatura  humedad  presion  p1  \
# 11216  2024    2   27     1    30        0           19       80      852   0
# 8084   2024    7    8     4     9        0           15       86      825   0
# 1474   2024    3   14     1    31        0           22       84        0   0
# 12353  2024    4   24    11    15        0           27       51      851   0
# 3915   2024    8   15     1    25        0           20       84        0   0
# ...     ...  ...  ...   ...   ...      ...          ...      ...      ...  ..
# 13435  2024    6   12    19    10        0           23       72      851   0
# 7763   2024    6   23     6    11        0           15       88      827   0
# 15377  2024    9    6    21    27        0           23       67      850   0
# 17730  2024    5   22    10    29        0           27       61      852   0
# 15725  2024    9   21    21    27        0           22       66      851   0
#
#        ...  dia_semana_Inicio Semana  dia_semana_Media semana  \
# 11216  ...                         1                        0
# 8084   ...                         1                        0
# 1474   ...                         0                        1
# 12353  ...                         1                        0
# 3915   ...                         0                        1
# ...    ...                       ...                      ...
# 13435  ...                         1                        0
# 7763   ...                         0                        0
# 15377  ...                         0                        1
# 17730  ...                         1                        0
# 15725  ...                         0                        0
#
#        estacion_Estacion Aranjuez  estacion_Estacion Belen  \
# 11216                           1                        0
# 8084                            0                        0
# 1474                            0                        0
# 12353                           1                        0
# 3915                            0                        0
# ...                           ...                      ...
# 13435                           1                        0
# 7763                            0                        0
# 15377                           1                        0
# 17730                           0                        1
# 15725                           1                        0
#
#        estacion_Estacion Caldas  estacion_Estacion Itagui  \
# 11216                         0                         0
# 8084                          1                         0
# 1474                          0                         1
# 12353                         0                         0
# 3915                          0                         1
# ...                         ...                       ...
# 13435                         0                         0
# 7763                          1                         0
# 15377                         0                         0
# 17730                         0                         0
# 15725                         0                         0
#
#        franja_horaria_Madrugada  franja_horaria_Mañana  franja_horaria_Noche  \
# 11216                         1                      0                     0
# 8084                          1                      0                     0
# 1474                          1                      0                     0
# 12353                         0                      1                     0
# 3915                          1                      0                     0
# ...                         ...                    ...                   ...
# 13435                         0                      0                     1
# 7763                          0                      1                     0
# 15377                         0                      0                     1
# 17730                         0                      1                     0
# 15725                         0                      0                     1
#
#        franja_horaria_Tarde
# 11216                     0
# 8084                      0
# 1474                      0
# 12353                     0
# 3915                      0
# ...                     ...
# 13435                     0
# 7763                      0
# 15377                     0
# 17730                     0
# 15725                     0
#
# [19447 rows x 25 columns]

# %%
# Separamos los datos de variables independientes y la variable dependiente
X = limpiaDataSetCalidadAire.drop(columns ='pm25')
y = limpiaDataSetCalidadAire['pm25']
# Separamos las columnas de las variables independientes de la dependiente
x_cols = X.columns.tolist()

# %%
# División de los datos en datos de entrenamiento del modelo, y datos para el testeo
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    train_size=0.7, # 70 % de nuestros datos en entrenamiento y 30% de los datos para el testeo
    random_state=1234,
    shuffle=True
)

# %%
#Escalar Variables númericas
pd.set_option('display.float_format', lambda x: '%.4f' % x)
scaler = joblib.load('data/stage/estandarizacionDataSet4.pkl')

# Se escalan los valores del dataset entrenamiento y prueba
X_train[x_cols] = scaler.fit_transform(X_train[x_cols])
X_test[x_cols] = scaler.transform(X_test[x_cols])
# Probamos diferentes kernel con hiperparametros para revisar sus evaluaciones
SVMR_linear = SVR(kernel='linear', C = 1000)
SVMR_Pol2 = SVR(kernel='poly', C = 100, degree = 2)
SVMR_Pol3 = SVR(kernel='poly', C = 100, degree = 3)
SVMR_rbf = SVR(kernel='rbf', C = 100)  # Disminuimos el parametro de regularizacion C para que no se tenga tanta diferencia entre las metricas de evaluación de datos de entrenamiento y testeo
# SVMR_sig = SVR(kernel='sigmoid', C = 1000)  # Observamos que el kernel sigmoide no refleja resultados esperados y lo excluimos para el analisis
# Entrenamos los modelos, dado que tenemos gran cantidad de datos toma un tiempo para la ejecución
SVMR_linear.fit(X_train, y_train)
SVMR_Pol2.fit(X_train, y_train)
SVMR_Pol3.fit(X_train, y_train)
SVMR_rbf.fit(X_train, y_train)
#SVMR_sig.fit(X_train, y_train)
print('Linear   Training: ', SVMR_linear.score(X_train,y_train), 'Test:',r2_score(y_test,SVMR_linear.predict(X_test)))
print('Poly 2   Training: ', SVMR_Pol2.score(X_train,y_train), 'Test:',r2_score(y_test,SVMR_Pol2.predict(X_test)))
print('Poly 3   Training: ', SVMR_Pol3.score(X_train,y_train), 'Test:',r2_score(y_test,SVMR_Pol3.predict(X_test)))
print('rbf      Training: ', SVMR_rbf.score(X_train,y_train), 'Test:',r2_score(y_test,SVMR_rbf.predict(X_test)))
#print('sigmoide Training: ', SVMR_sig.score(X_train,y_train), 'Test:',r2_score(y_test,SVMR_sig.predict(X_test)))
# Out:
# Linear   Training:  0.1773573465251853 Test: 0.18930319587891553
# Poly 2   Training:  0.3047927153853718 Test: 0.2998748858889463
# Poly 3   Training:  0.4229661581884916 Test: 0.38931370249483677
# rbf      Training:  0.4465240185131295 Test: 0.376663326638621

# %%
# luego de la ejecución de los modelos con los hiperparametros predeterminados usamos validación cruzada en 5 pliegues
cross_val_score(SVMR_rbf, X, y, cv=5, scoring='r2')
# Out:
# array([0.05387946, 0.04918886, 0.06417908, 0.07200873, 0.0563894 ,
#        0.0724363 , 0.06993513, 0.05193737, 0.04847333, 0.06387322])

# %% [markdown]
# Tunning Afinación del modelo

# %%
# Nuevamente se asigna a 'X_Completo' y 'y_Completo' los datos entrada y salida respectivamente
X_completo = X
y_completo = y

# Se escalan los datos numéricos de entrada
X_completo[x_cols] = scaler.transform(X_completo[x_cols])
X_completo
# Out:
#         anio    mes    dia   hora  festivo  temperatura  humedad  presion  \
# 11216 0.0000 0.1250 0.8667 0.0435   0.0000       0.3182   0.7791   0.9953
# 8084  0.0000 0.7500 0.2333 0.1739   0.0000       0.1364   0.8488   0.9638
# 1474  0.0000 0.2500 0.4333 0.0435   0.0000       0.4545   0.8256   0.0000
# 12353 0.0000 0.3750 0.7667 0.4783   0.0000       0.6818   0.4419   0.9942
# 3915  0.0000 0.8750 0.4667 0.0435   0.0000       0.3636   0.8256   0.0000
# ...      ...    ...    ...    ...      ...          ...      ...      ...
# 13435 0.0000 0.6250 0.3667 0.8261   0.0000       0.5000   0.6860   0.9942
# 7763  0.0000 0.6250 0.7333 0.2609   0.0000       0.1364   0.8721   0.9661
# 15377 0.0000 1.0000 0.1667 0.9130   0.0000       0.5000   0.6279   0.9930
# 17730 0.0000 0.5000 0.7000 0.4348   0.0000       0.6818   0.5581   0.9953
# 15725 0.0000 1.0000 0.6667 0.9130   0.0000       0.4545   0.6163   0.9942
#
#           p1  velocidad_prom  ...  dia_semana_Inicio Semana  \
# 11216 0.0000          0.0000  ...                    1.0000
# 8084  0.0000          0.0000  ...                    1.0000
# 1474  0.0000          0.1667  ...                    0.0000
# 12353 0.0000          0.1667  ...                    1.0000
# 3915  0.0000          0.1667  ...                    0.0000
# ...      ...             ...  ...                       ...
# 13435 0.0000          0.3333  ...                    1.0000
# 7763  0.0000          0.0000  ...                    0.0000
# 15377 0.0000          0.3333  ...                    0.0000
# 17730 0.0000          0.0000  ...                    1.0000
# 15725 0.0000          0.0000  ...                    0.0000
#
#        dia_semana_Media semana  estacion_Estacion Aranjuez  \
# 11216                   0.0000                      1.0000
# 8084                    0.0000                      0.0000
# 1474                    1.0000                      0.0000
# 12353                   0.0000                      1.0000
# 3915                    1.0000                      0.0000
# ...                        ...                         ...
# 13435                   0.0000                      1.0000
# 7763                    0.0000                      0.0000
# 15377                   1.0000                      1.0000
# 17730                   0.0000                      0.0000
# 15725                   0.0000                      1.0000
#
#        estacion_Estacion Belen  estacion_Estacion Caldas  \
# 11216                   0.0000                    0.0000
# 8084                    0.0000                    1.0000
# 1474                    0.0000                    0.0000
# 12353                   0.0000                    0.0000
# 3915                    0.0000                    0.0000
# ...                        ...                       ...
# 13435                   0.0000                    0.0000
# 7763                    0.0000                    1.0000
# 15377                   0.0000                    0.0000
# 17730                   1.0000                    0.0000
# 15725                   0.0000                    0.0000
#
#        estacion_Estacion Itagui  franja_horaria_Madrugada  \
# 11216                    0.0000                    1.0000
# 8084                     0.0000                    1.0000
# 1474                     1.0000                    1.0000
# 12353                    0.0000                    0.0000
# 3915                     1.0000                    1.0000
# ...                         ...                       ...
# 13435                    0.0000                    0.0000
# 7763                     0.0000                    0.0000
# 15377                    0.0000                    0.0000
# 17730                    0.0000                    0.0000
# 15725                    0.0000                    0.0000
#
#        franja_horaria_Mañana  franja_horaria_Noche  franja_horaria_Tarde
# 11216                 0.0000                0.0000                0.0000
# 8084                  0.0000                0.0000                0.0000
# 1474                  0.0000                0.0000                0.0000
# 12353                 1.0000                0.0000                0.0000
# 3915                  0.0000                0.0000                0.0000
# ...                      ...                   ...                   ...
# 13435                 0.0000                1.0000                0.0000
# 7763                  1.0000                0.0000                0.0000
# 15377                 0.0000                1.0000                0.0000
# 17730                 1.0000                0.0000                0.0000
# 15725                 0.0000                1.0000                0.0000
#
# [19447 rows x 24 columns]

# %%
#Se entena el modelo con múltiples hiperparámetros para encontrar el mejor que se adapte

#Se crea una instancia de una SVR Regression
modelsvr = SVR()

# Usamos 5 pliegues
CV = 5

#Se establecen los hiperparámetros para el Kernel lineal
svm_linear = {'C': [0.1, 1],
              'kernel': ['linear']}

#Se establecen los hiperparámetros para el Kernel polinomico
svm_poly = {'C': [0.1, 1],
              'gamma': [1, 0.1, 'auto', 'scale'],
              'degree': [2, 3],
              'kernel': ['poly']}

#Se establecen los hiperparámetros para los kernels rbf
svm_others = {'C': [0.1, 1],
              'gamma': [1, 0.1,'auto', 'scale'],
              'kernel': [ 'rbf']}

#Se unen todos los hiperparametros en una lista de diccionarios
parameters = [svm_linear, svm_poly, svm_others]

# Se define un GridSearchCV con una validacion cruzada de 5 pliegues y con todos los
#hierparametros establecidos anteriormente
grid_svr = GridSearchCV(modelsvr, param_grid=parameters, cv=CV, verbose=3)

#Se entrena el GridSearchCV anterior (2 min. aprox.) con los datos completos
grid_svr.fit(X_completo,y_completo)
# Out:
# Fitting 5 folds for each of 26 candidates, totalling 130 fits
# [CV 1/5] END ..............C=0.1, kernel=linear;, score=0.162 total time=  16.0s
# [CV 2/5] END ..............C=0.1, kernel=linear;, score=0.185 total time=  16.0s
# [CV 3/5] END ..............C=0.1, kernel=linear;, score=0.186 total time=  16.2s
# [CV 4/5] END ..............C=0.1, kernel=linear;, score=0.189 total time=  16.5s
# [CV 5/5] END ..............C=0.1, kernel=linear;, score=0.165 total time=  15.8s
# [CV 1/5] END ................C=1, kernel=linear;, score=0.163 total time=  15.9s
# [CV 2/5] END ................C=1, kernel=linear;, score=0.186 total time=  18.3s
# [CV 3/5] END ................C=1, kernel=linear;, score=0.187 total time=  16.0s
# [CV 4/5] END ................C=1, kernel=linear;, score=0.190 total time=  15.8s
# [CV 5/5] END ................C=1, kernel=linear;, score=0.166 total time=  16.1s
# [CV 1/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.235 total time=  17.1s
# [CV 2/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.265 total time=  17.1s
# [CV 3/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.270 total time=  17.1s
# [CV 4/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.255 total time=  18.5s
# [CV 5/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.241 total time=  17.9s
# [CV 1/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.141 total time=  16.8s
# [CV 2/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.163 total time=  16.9s
# [CV 3/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.160 total time=  19.2s
# [CV 4/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.164 total time=  17.4s
# [CV 5/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.147 total time=  18.5s
# [CV 1/5] END C=0.1, degree=2, gamma=auto, kernel=poly;, score=0.050 total time=  17.3s
# [CV 2/5] END C=0.1, degree=2, gamma=auto, kernel=poly;, score=0.071 total time=  17.2s
# [CV 3/5] END C=0.1, degree=2, gamma=auto, kernel=poly;, score=0.068 total time=  17.0s
# [CV 4/5] END C=0.1, degree=2, gamma=auto, kernel=poly;, score=0.068 total time=  17.2s
# [CV 5/5] END C=0.1, degree=2, gamma=auto, kernel=poly;, score=0.060 total time=  17.6s
# [CV 1/5] END C=0.1, degree=2, gamma=scale, kernel=poly;, score=0.193 total time=  18.4s
# [CV 2/5] END C=0.1, degree=2, gamma=scale, kernel=poly;, score=0.218 total time=  17.2s
# [CV 3/5] END C=0.1, degree=2, gamma=scale, kernel=poly;, score=0.220 total time=  16.7s
# [CV 4/5] END C=0.1, degree=2, gamma=scale, kernel=poly;, score=0.216 total time=  19.0s
# [CV 5/5] END C=0.1, degree=2, gamma=scale, kernel=poly;, score=0.200 total time=  16.6s
# [CV 1/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.297 total time=  19.5s
# [CV 2/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.337 total time=  21.7s
# [CV 3/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.332 total time=  19.5s
# [CV 4/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.313 total time=  20.6s
# [CV 5/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.307 total time=  20.9s
# [CV 1/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.116 total time=  17.1s
# [CV 2/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.138 total time=  17.1s
# [CV 3/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.135 total time=  17.2s
# [CV 4/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.136 total time=  22.3s
# [CV 5/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.123 total time=  17.5s
# [CV 1/5] END C=0.1, degree=3, gamma=auto, kernel=poly;, score=-0.004 total time=  17.9s
# [CV 2/5] END C=0.1, degree=3, gamma=auto, kernel=poly;, score=0.016 total time=  17.9s
# [CV 3/5] END C=0.1, degree=3, gamma=auto, kernel=poly;, score=0.013 total time=  18.5s
# [CV 4/5] END C=0.1, degree=3, gamma=auto, kernel=poly;, score=0.011 total time=  18.7s
# [CV 5/5] END C=0.1, degree=3, gamma=auto, kernel=poly;, score=0.008 total time=  17.7s
# [CV 1/5] END C=0.1, degree=3, gamma=scale, kernel=poly;, score=0.211 total time=  18.5s
# [CV 2/5] END C=0.1, degree=3, gamma=scale, kernel=poly;, score=0.238 total time=  17.3s
# [CV 3/5] END C=0.1, degree=3, gamma=scale, kernel=poly;, score=0.242 total time=  18.6s
# [CV 4/5] END C=0.1, degree=3, gamma=scale, kernel=poly;, score=0.232 total time=  19.7s
# [CV 5/5] END C=0.1, degree=3, gamma=scale, kernel=poly;, score=0.219 total time=  21.1s
# [CV 1/5] END C=1, degree=2, gamma=1, kernel=poly;, score=0.262 total time=  23.7s
# [CV 2/5] END C=1, degree=2, gamma=1, kernel=poly;, score=0.298 total time=  21.1s
# [CV 3/5] END C=1, degree=2, gamma=1, kernel=poly;, score=0.302 total time=  20.2s
# [CV 4/5] END C=1, degree=2, gamma=1, kernel=poly;, score=0.279 total time=  22.2s
# [CV 5/5] END C=1, degree=2, gamma=1, kernel=poly;, score=0.272 total time=  19.4s
# [CV 1/5] END C=1, degree=2, gamma=0.1, kernel=poly;, score=0.199 total time=  16.9s
# [CV 2/5] END C=1, degree=2, gamma=0.1, kernel=poly;, score=0.225 total time=  17.1s
# [CV 3/5] END C=1, degree=2, gamma=0.1, kernel=poly;, score=0.228 total time=  18.5s
# [CV 4/5] END C=1, degree=2, gamma=0.1, kernel=poly;, score=0.222 total time=  19.0s
# [CV 5/5] END C=1, degree=2, gamma=0.1, kernel=poly;, score=0.205 total time=  18.1s
# [CV 1/5] END C=1, degree=2, gamma=auto, kernel=poly;, score=0.160 total time=  16.9s
# [CV 2/5] END C=1, degree=2, gamma=auto, kernel=poly;, score=0.184 total time=  17.0s
# [CV 3/5] END C=1, degree=2, gamma=auto, kernel=poly;, score=0.181 total time=  17.0s
# [CV 4/5] END C=1, degree=2, gamma=auto, kernel=poly;, score=0.184 total time=  16.8s
# [CV 5/5] END C=1, degree=2, gamma=auto, kernel=poly;, score=0.165 total time=  18.0s
# [CV 1/5] END C=1, degree=2, gamma=scale, kernel=poly;, score=0.230 total time=  18.2s
# [CV 2/5] END C=1, degree=2, gamma=scale, kernel=poly;, score=0.259 total time=  17.2s
# [CV 3/5] END C=1, degree=2, gamma=scale, kernel=poly;, score=0.264 total time=  17.1s
# [CV 4/5] END C=1, degree=2, gamma=scale, kernel=poly;, score=0.250 total time=  17.3s
# [CV 5/5] END C=1, degree=2, gamma=scale, kernel=poly;, score=0.236 total time=  20.7s
# [CV 1/5] END C=1, degree=3, gamma=1, kernel=poly;, score=0.355 total time=  55.1s
# [CV 2/5] END C=1, degree=3, gamma=1, kernel=poly;, score=0.394 total time=  57.1s
# [CV 3/5] END C=1, degree=3, gamma=1, kernel=poly;, score=0.378 total time=  57.3s
# [CV 4/5] END C=1, degree=3, gamma=1, kernel=poly;, score=0.367 total time=  53.9s
# [CV 5/5] END C=1, degree=3, gamma=1, kernel=poly;, score=0.366 total time=  52.3s
# [CV 1/5] END C=1, degree=3, gamma=0.1, kernel=poly;, score=0.196 total time=  16.7s
# [CV 2/5] END C=1, degree=3, gamma=0.1, kernel=poly;, score=0.223 total time=  16.9s
# [CV 3/5] END C=1, degree=3, gamma=0.1, kernel=poly;, score=0.225 total time=  16.8s
# [CV 4/5] END C=1, degree=3, gamma=0.1, kernel=poly;, score=0.220 total time=  17.6s
# [CV 5/5] END C=1, degree=3, gamma=0.1, kernel=poly;, score=0.205 total time=  18.2s
# [CV 1/5] END C=1, degree=3, gamma=auto, kernel=poly;, score=0.098 total time=  17.5s
# [CV 2/5] END C=1, degree=3, gamma=auto, kernel=poly;, score=0.121 total time=  19.2s
# [CV 3/5] END C=1, degree=3, gamma=auto, kernel=poly;, score=0.117 total time=  17.0s
# [CV 4/5] END C=1, degree=3, gamma=auto, kernel=poly;, score=0.118 total time=  17.9s
# [CV 5/5] END C=1, degree=3, gamma=auto, kernel=poly;, score=0.106 total time=  18.4s
# [CV 1/5] END C=1, degree=3, gamma=scale, kernel=poly;, score=0.260 total time=  17.3s
# [CV 2/5] END C=1, degree=3, gamma=scale, kernel=poly;, score=0.294 total time=  17.4s
# [CV 3/5] END C=1, degree=3, gamma=scale, kernel=poly;, score=0.297 total time=  17.6s
# [CV 4/5] END C=1, degree=3, gamma=scale, kernel=poly;, score=0.277 total time=  18.6s
# [CV 5/5] END C=1, degree=3, gamma=scale, kernel=poly;, score=0.269 total time=  18.7s
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.154 total time=  21.4s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.177 total time=  25.7s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.175 total time=  22.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.176 total time=  23.8s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.165 total time=  22.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.161 total time=  23.5s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.183 total time=  23.1s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.183 total time=  22.8s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.185 total time=  24.6s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.166 total time=  22.1s
# [CV 1/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.136 total time=  26.0s
# [CV 2/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.157 total time=  23.2s
# [CV 3/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.156 total time=  22.4s
# [CV 4/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.160 total time=  24.0s
# [CV 5/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.142 total time=  21.8s
# [CV 1/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.180 total time=  23.4s
# [CV 2/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.204 total time=  21.1s
# [CV 3/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.204 total time=  23.5s
# [CV 4/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.204 total time=  21.8s
# [CV 5/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.187 total time=  25.7s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.255 total time=  23.2s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.284 total time=  21.9s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.285 total time=  23.9s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.277 total time=  21.6s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.264 total time=  23.5s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.208 total time=  21.3s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.232 total time=  23.6s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.236 total time=  21.7s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.230 total time=  25.9s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.214 total time=  21.8s
# [CV 1/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.185 total time=  23.1s
# [CV 2/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.207 total time=  21.8s
# [CV 3/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.208 total time=  23.1s
# [CV 4/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.209 total time=  22.5s
# [CV 5/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.189 total time=  22.6s
# [CV 1/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.235 total time=  22.6s
# [CV 2/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.263 total time=  21.7s
# [CV 3/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.266 total time=  25.8s
# [CV 4/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.254 total time=  21.5s
# [CV 5/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.241 total time=  23.7s
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid=[{'C': [0.1, 1], 'kernel': ['linear']},
#                          {'C': [0.1, 1], 'degree': [2, 3],
#                           'gamma': [1, 0.1, 'auto', 'scale'],
#                           'kernel': ['poly']},
#                          {'C': [0.1, 1], 'gamma': [1, 0.1, 'auto', 'scale'],
#                           'kernel': ['rbf']}],
#              verbose=3)

# %%
# Obtener los resultados del grid search en un dataframe para manipular
results_grid_svr = pd.DataFrame(grid_svr.cv_results_)

# Seleccionar las columnas deseadas
columns_grid_svr = ['param_C']  + \
                    ['param_degree']  + \
                    ['param_kernel']  + \
                    ['param_gamma']   + \
                    ['mean_test_score', 'std_test_score']  + \
                    [f'split{i}_test_score' for i in range(CV)]

# Filtrar y mostrar los resultados
results_grid_svr_filtered = results_grid_svr[columns_grid_svr]

# Crear la columna scoreWithStd: f1 / std
results_grid_svr_filtered['scoreWithStd'] = results_grid_svr_filtered.apply(
    lambda row: row['mean_test_score'] / row['std_test_score'] if row['std_test_score'] != 0 else 0,
    axis=1
)

# Encuentra el índice del máximo valor en la columna scoreWithStd
indice_max_scoreWithStd = results_grid_svr_filtered['scoreWithStd'].idxmax()

# Mostrar los scores promedios por cada parámetro
print(results_grid_svr_filtered[['param_C', 'param_degree', 'mean_test_score', 'std_test_score', 'scoreWithStd']])
# Out:
#     param_C  param_degree  mean_test_score  std_test_score  scoreWithStd
# 0    0.1000           NaN           0.1775          0.0113       15.7298
# 1    1.0000           NaN           0.1783          0.0114       15.6482
# 2    0.1000        2.0000           0.2535          0.0134       18.8535
# 3    0.1000        2.0000           0.1551          0.0092       16.8080
# 4    0.1000        2.0000           0.0634          0.0076        8.3689
# 5    0.1000        2.0000           0.2095          0.0110       18.9986
# 6    0.1000        3.0000           0.3173          0.0152       20.9040
# 7    0.1000        3.0000           0.1297          0.0087       14.9089
# 8    0.1000        3.0000           0.0088          0.0068        1.3019
# 9    0.1000        3.0000           0.2285          0.0116       19.7519
# 10   1.0000        2.0000           0.2827          0.0153       18.5327
# 11   1.0000        2.0000           0.2156          0.0114       18.9777
# 12   1.0000        2.0000           0.1750          0.0102       17.1401
# 13   1.0000        2.0000           0.2479          0.0130       19.0133
# 14   1.0000        3.0000           0.3720          0.0130       28.5417
# 15   1.0000        3.0000           0.2139          0.0114       18.7231
# 16   1.0000        3.0000           0.1121          0.0085       13.1494
# 17   1.0000        3.0000           0.2795          0.0142       19.6893
# 18   0.1000           NaN           0.1691          0.0088       19.1237
# 19   0.1000           NaN           0.1756          0.0102       17.2765
# 20   0.1000           NaN           0.1502          0.0092       16.2414
# 21   0.1000           NaN           0.1959          0.0101       19.4241
# 22   1.0000           NaN           0.2727          0.0116       23.5500
# 23   1.0000           NaN           0.2242          0.0109       20.5004
# 24   1.0000           NaN           0.1995          0.0106       18.7919
# 25   1.0000           NaN           0.2516          0.0120       20.8997
# <ipython-input-10-4471c8a65a28>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_grid_svr_filtered['scoreWithStd'] = results_grid_svr_filtered.apply(

# %%
# Se identifican los mejores hiperparámetros
best_params = grid_svr.best_params_
print('Best Parameters : ',best_params)
# Out:
# Best Parameters :  {'C': 1, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}

# %%
# Top 3 de los mejores scores
results_grid_svr_filtered.sort_values(by='scoreWithStd', ascending=False).head(3)[
    ['param_C', 'param_degree', 'param_kernel','param_gamma','mean_test_score', 'std_test_score', 'scoreWithStd']]
# Out:
#     param_C  param_degree param_kernel param_gamma  mean_test_score  \
# 14   1.0000        3.0000         poly           1           0.3720
# 22   1.0000           NaN          rbf           1           0.2727
# 6    0.1000        3.0000         poly           1           0.3173
#
#     std_test_score  scoreWithStd
# 14          0.0130       28.5417
# 22          0.0116       23.5500
# 6           0.0152       20.9040

# %%
# Seleccionar el registro correspondiente al índice máximo
registro_max_scoreWithStd = results_grid_svr_filtered.loc[indice_max_scoreWithStd]

registro_max_scoreWithStd.transpose()
# Out:
# param_C              1.0000
# param_degree         3.0000
# param_kernel           poly
# param_gamma               1
# mean_test_score      0.3720
# std_test_score       0.0130
# split0_test_score    0.3549
# split1_test_score    0.3935
# split2_test_score    0.3781
# split3_test_score    0.3674
# split4_test_score    0.3661
# scoreWithStd        28.5417
# Name: 14, dtype: object

# %%
# Se crea un modelo SVR con los mejores hiperparámetros
modelsvr = SVR( kernel = best_params["kernel"]
                    , gamma = best_params["gamma"]
                    , C= best_params["C"]
                    , degree = best_params["degree"])


#Se entrena el modelo con los datos completos
modelsvr.fit(X_completo, y_completo)
# Out:
# SVR(C=1, gamma=1, kernel='poly')

# %%
#Se guardan los modelos de SVC

joblib.dump(modelsvr, 'data/analytics/modelosPM25/SVR_CV_varios_cal_aire_pm25.pkl')
